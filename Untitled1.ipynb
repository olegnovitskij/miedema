# %%
import kivy
# Out:
# [WARNING] [Config      ] Older configuration version detected (0 instead of 21)
# [WARNING] [Config      ] Upgrading configuration in progress.
# [INFO   ] [Logger      ] Record log in /Users/19980377/.kivy/logs/kivy_23-02-15_0.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "/Users/19980377/opt/anaconda3/envs/myenv/lib/python3.10/site-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:31:57) [Clang 14.0.6 ]
# [INFO   ] [Python      ] Interpreter at "/Users/19980377/opt/anaconda3/envs/myenv/bin/python"
#  UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).
#  UsageError: %%python is a cell magic, but the cell body is empty.
#  UsageError: Cell magic `%%run` not found (But line magic `%run` exists, did you mean that instead?).
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_imageio, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL ES 2" graphics system
# [INFO   ] [GL          ] Backend used <sdl2>
# [INFO   ] [GL          ] OpenGL version <b'2.1 INTEL-20.2.50'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) Iris(TM) Plus Graphics 645'>
# [INFO   ] [GL          ] OpenGL parsed version: 2, 1
# [INFO   ] [GL          ] Shading version <b'1.20'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <16>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
# %run ./main.py
# Out:
# Unexpected exception formatting exception. Falling back to standard exception

# %%
<VisualizationWindow>:
    FloatLayout:
        id: fl_visu
        canvas.before:
            Color:
                rgba: (252/255, 245/255, 225/255, 1)
            Rectangle:
                size: self.size
                pos: self.pos 
        Button:
            pos_hint:{"x":0.6, "y": 0.35}
            size_hint:0.05,0.05
            text: "<-"
            on_release: 
                app.root.current = "main"
                root.manager.transition.direction = "right"
            background_color: (102/255, 46/255, 31/255, 1)

<MainWindow>:
    el_1: el_1
    x_1: x_1
    y_1: y_1
    z_1: z_1
    occ_1: occ_1
    el_2: el_2
    x_2: x_2
    y_2: y_2
    z_2: z_2
    occ_2: occ_2
    el_3: el_3
    x_3: x_3
    y_3: y_3
    z_3: z_3
    occ_3: occ_3
    h: h
    
    FloatLayout:
        GridLayout:
            rows: 6
            cols: 2
            padding: [0, 0, 0, 25]
            spacing: [10,0]
  
        Label:
            pos_hint:{"x": 0.25, "top":0.9}
            size_hint:0.1, 0.1
            text: "elem"

        Label:
            pos_hint:{"x": 0.35, "top":0.9}
            size_hint:0.1, 0.1
            text: "x"

        Label:
            pos_hint:{"x": 0.45, "top":0.9}
            size_hint:0.1, 0.1
            text: "y"
            
        Label:
            pos_hint:{"x": 0.55, "top":0.9}
            size_hint:0.1, 0.1
            text: "z"
            
        Label:
            pos_hint:{"x": 0.65, "top":0.9}
            size_hint:0.1, 0.1
            text: "occ"
            
          
        
        TextInput:
            id: el_1
            multiline: False
            pos_hint: {"x": 0.25, "top":0.8}
            size_hint: 0.1, 0.1
            
        
        TextInput:
            id: x_1
            multiline: False
            pos_hint: {"x": 0.35, "top":0.8}
            size_hint: 0.1, 0.1
            
        
        TextInput:
            id: y_1
            multiline: False
            pos_hint: {"x": 0.45, "top":0.8}
            size_hint: 0.1, 0.1
            

        TextInput:
            id: z_1
            multiline: False
            pos_hint: {"x": 0.55, "top":0.8}
            size_hint: 0.1, 0.1
            
            
        TextInput:
            id: occ_1
            multiline: False
            pos_hint: {"x": 0.65, "top":0.8}
            size_hint: 0.1, 0.1            
            text: "1"
            

        TextInput:
            id: el_2
            multiline: False
            pos_hint: {"x": 0.25, "top":0.7}
            size_hint: 0.1, 0.1
            
        
        TextInput:
            id: x_2
            multiline: False
            pos_hint: {"x": 0.35, "top":0.7}
            size_hint: 0.1, 0.1
            
        
        TextInput:
            id: y_2
            multiline: False
            pos_hint: {"x": 0.45, "top":0.7}
            size_hint: 0.1, 0.1
            

        TextInput:
            id: z_2
            multiline: False
            pos_hint: {"x": 0.55, "top":0.7}
            size_hint: 0.1, 0.1
            
            
        TextInput:
            id: occ_2
            multiline: False
            pos_hint: {"x": 0.65, "top":0.7}
            size_hint: 0.1, 0.1   
            text: "1"


        TextInput:
            id: el_3
            multiline: False
            pos_hint: {"x": 0.25, "top":0.6}
            size_hint: 0.1, 0.1
            
        
        TextInput:
            id: x_3
            multiline: False
            pos_hint: {"x": 0.35, "top":0.6}
            size_hint: 0.1, 0.1
            
        
        TextInput:
            id: y_3
            multiline: False
            pos_hint: {"x": 0.45, "top":0.6}
            size_hint: 0.1, 0.1
            

        TextInput:
            id: z_3
            multiline: False
            pos_hint: {"x": 0.55, "top":0.6}
            size_hint: 0.1, 0.1
            
            
        TextInput:
            id: occ_3
            multiline: False
            pos_hint: {"x": 0.65, "top":0.6}
            size_hint: 0.1, 0.1   
            text: "1"
            
            
        Label:
            id: h
            pos_hint:{"x": 0.4, "top":0.5}
            size_hint: 0.2, 0.2
            text: "H ="  
            
        Button:
            pos_hint:{"x":0.2, "y": 0.1}
            size_hint:0.6,0.2
            text: "Start"
            on_release: root.press_button()

# %%
    chem_elem_1:chem_elem
    x_1:x_1
    y_1:y_1
    z_1:z_1
    op_1:op_1 
                padding: [1000, 100, 200, 500]
            spacing: [0,0]
            
<BeautyTextInput@TextInput>:
    font_size: "20sp"
    bold: True
    color: [1,1,0,1]
    halign: "center"
    text_size: root.width, None
    size: self.texture_size

# %%
            Label:
                text: 'alpha'
            
            TextInput:
                id: alpha
                multiline: False            

                
            Label:
                text: 'beta'
            
            TextInput:
                id: beta
                multiline: False                 

                
            Label:
                text: 'gamma'
            
            TextInput:
                id: gamma
                multiline: False

# %%
import kivy.garden
# Out:
# [INFO   ] [Logger      ] Record log in /Users/19980377/.kivy/logs/kivy_23-02-20_51.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "/Users/19980377/opt/anaconda3/envs/myenv/lib/python3.10/site-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:31:57) [Clang 14.0.6 ]
# [INFO   ] [Python      ] Interpreter at "/Users/19980377/opt/anaconda3/envs/myenv/bin/python"

# %%
from garden.matplotlib.backend_kivyagg import FigureCanvasKivyAgg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from garden.matplotlib.backend_kivyagg import FigureCanvasKivyAgg
#
# ModuleNotFoundError: No module named 'garden.matplotlib'

# %%
# !ls
# Out:
# Enthalpy_calculation.py
# H_calc.ipynb
# Kivy-2.1.0.tar.gz
# Untitled.ipynb
# Untitled1.ipynb
# __pycache__
# crystal_parameters.xlsx
# database.py
# garden.matplotlib
# garden.matplotlib.zip
# input_structure.txt
# main.py
# miedema_coefficients.xlsx
# miedema_v0.ipynb
# my.kv
# periodic_table.json
# table (1).xlsx
# users.txt
# ~$crystal_parameters.xlsx
# нир 4 курс.pdf
# текст программы с вопросами.txt
